# %% [markdown]
# ### This Script Contains The Following Points ###

# %% [markdown]
# ### 1. Imports and Subset Creation
# ### 2. Grouping Data in Subset
# ### 3. Aggregating Data
# ### 4. Aggregating with Transform
# ### 5. Deriving Columns with loc()
# ### 6. Spending Flag

# %% [markdown]
# ## 1. Imports and Subset Creation

# %%
import pandas as pd
import numpy as np
import os

# %%
# creating path
path = r'/Users/kimkmiz/Documents/Instacart Basket Analysis 2024'

# %%
#import orders_products_merged from previous lesson
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'IC24 Prepared Data', 'ords_prods_merge_derived.pkl'))

# %%
#create a subset called df of the first million entries
df = ords_prods_merge[:1000000]

# %%
# Check shape of new subset
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
# 5           0           1  Chocolate Sandwich Cookies        61
# 6           0           1  Chocolate Sandwich Cookies        61
# 7           0           1  Chocolate Sandwich Cookies        61
# 8           0           1  Chocolate Sandwich Cookies        61
# 9           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id  order_number  order_day_of_week  \
# 0             19     5.8   3139998      138            28                  6
# 1             19     5.8   1977647      138            30                  6
# 2             19     5.8    389851      709             2                  0
# 3             19     5.8    652770      764             1                  3
# 4             19     5.8   1813452      764             3                  4
# 5             19     5.8   1701441      777            16                  1
# 6             19     5.8   1871483      825             3                  2
# 7             19     5.8   1290456      910            12                  3
# 8             19     5.8    369558     1052            10                  1
# 9             19     5.8    589712     1052            15                  1
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                 11                     3.0                  5          0
# 1                 17                    20.0                  1          1
# 2                 21                     6.0                 20          0
# 3                 13                     NaN                 10          0
# 4                 17                     9.0                 11          1
# 5                  7                    26.0                  7          0
# 6                 14                    30.0                  2          0
# 7                 10                    30.0                  1          0
# 8                 20                    19.0                  1          0
# 9                 12                    15.0                  2          1
#
#   _merge    price_range_loc    busiest_days busiest_period_of_day
# 0   both  Mid-range product  Regularly busy           Most orders
# 1   both  Mid-range product  Regularly busy        Average orders
# 2   both  Mid-range product    Busiest days        Average orders
# 3   both  Mid-range product    Slowest days           Most orders
# 4   both  Mid-range product    Slowest days        Average orders
# 5   both  Mid-range product    Busiest days        Average orders
# 6   both  Mid-range product  Regularly busy           Most orders
# 7   both  Mid-range product    Slowest days           Most orders
# 8   both  Mid-range product    Busiest days        Average orders
# 9   both  Mid-range product    Busiest days           Most orders

# %% [markdown]
# ### Observations:
# - the subset is long
# - the unnamed column is not needed
# - the first 10 rows are all from the same aisle, same product 'chocolate sandwich cookies'

# %% [markdown]
# ## 2. Grouping Data in Subset

# %%
#group data from subset by product name
df.groupby('product_name')

# %%
#this function is not visible
#this is only the first step of the workflow
#need to aggregate or apply a function next

# %% [markdown]
# ## 3. Aggregating Data

# %%
#split data into groups based on 'department_id'
#apply the agg() function to each group to get mean values of the 'order_number' column
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# The groupby() function is assigned to the df dataframe, creating a pandas object for the 'department_id'
# The agg() function is applied to this object, returning the mean of the given column 'order_id'
# The table lists all possible 'department_id' values from the df with corresponding “order_number” means

# %%
# There are some aggregations that can be conducted without the use of the agg() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
#When using agg(), put the column you want to aggregate inside the parenthesis of the agg()
#When using mean(), simply index the column with square brackets, then follow it with the function you want to use after the dot

# %%
#Dot notation vs. square brackets
#df.groupby('department_id').order_number.mean()
#Using dot notation results in the same output , however, there are reasons you shouldn't
#Square brackets stand out and are more readable 
#Square brackets have no other role in Python beyond indexing, so using dot notation can make it slower since it has to work harder to understand

# %%
#perform multiple aggregations at once
#find mean, min and max
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ## 4. Aggregating with Transform

# %%
#Create a flag for 'loyalty' customers
#'Loyalty' customers are those who come back time and time again to use the service or buy products
#Loyal customer = max orders are over 40
#Regular customer = max orders are over 10 but less than or equal to 40
#New Customer = max orders are less than or equal to 10

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/sl/t5s1mv992pz285_hqs7tzfh80000gr/T/ipykernel_26295/1681540670.py:1: FutureWarning: The provided callable <function max at 0x106d2c400> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            0           1  Chocolate Sandwich Cookies        61
# 2            0           1  Chocolate Sandwich Cookies        61
# 3            0           1  Chocolate Sandwich Cookies        61
# 4            0           1  Chocolate Sandwich Cookies        61
# 5            0           1  Chocolate Sandwich Cookies        61
# 6            0           1  Chocolate Sandwich Cookies        61
# 7            0           1  Chocolate Sandwich Cookies        61
# 8            0           1  Chocolate Sandwich Cookies        61
# 9            0           1  Chocolate Sandwich Cookies        61
# 10           0           1  Chocolate Sandwich Cookies        61
# 11           0           1  Chocolate Sandwich Cookies        61
# 12           0           1  Chocolate Sandwich Cookies        61
# 13           0           1  Chocolate Sandwich Cookies        61
# 14           0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  order_id  user_id  order_number  order_day_of_week  \
# 0              19     5.8   3139998      138            28                  6
# 1              19     5.8   1977647      138            30                  6
# 2              19     5.8    389851      709             2                  0
# 3              19     5.8    652770      764             1                  3
# 4              19     5.8   1813452      764             3                  4
# 5              19     5.8   1701441      777            16                  1
# 6              19     5.8   1871483      825             3                  2
# 7              19     5.8   1290456      910            12                  3
# 8              19     5.8    369558     1052            10                  1
# 9              19     5.8    589712     1052            15                  1
# 10             19     5.8   1798115     1379             1                  5
# 11             19     5.8    497193     1480            36                  3
# 12             19     5.8   1727826     1480            38                  4
# 13             19     5.8   2694698     1480            39                  2
# 14             19     5.8   3171753     1494             6                  3
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     NaN                 10          0
# 4                  17                     9.0                 11          1
# 5                   7                    26.0                  7          0
# 6                  14                    30.0                  2          0
# 7                  10                    30.0                  1          0
# 8                  20                    19.0                  1          0
# 9                  12                    15.0                  2          1
# 10                 11                     NaN                  1          0
# 11                 13                     7.0                  1          0
# 12                 13                     7.0                  3          1
# 13                 12                    12.0                  4          1
# 14                 10                     2.0                  8          0
#
#    _merge    price_range_loc    busiest_days busiest_period_of_day  max_order
# 0    both  Mid-range product  Regularly busy           Most orders         32
# 1    both  Mid-range product  Regularly busy        Average orders         32
# 2    both  Mid-range product    Busiest days        Average orders          5
# 3    both  Mid-range product    Slowest days           Most orders          3
# 4    both  Mid-range product    Slowest days        Average orders          3
# 5    both  Mid-range product    Busiest days        Average orders         26
# 6    both  Mid-range product  Regularly busy           Most orders          9
# 7    both  Mid-range product    Slowest days           Most orders         12
# 8    both  Mid-range product    Busiest days        Average orders         20
# 9    both  Mid-range product    Busiest days           Most orders         20
# 10   both  Mid-range product  Regularly busy           Most orders         10
# 11   both  Mid-range product    Slowest days           Most orders         43
# 12   both  Mid-range product    Slowest days           Most orders         43
# 13   both  Mid-range product  Regularly busy           Most orders         43
# 14   both  Mid-range product    Slowest days           Most orders         13

# %%
#New 'max_order' column at the end of df
#Each value in this column corresponds to the max number of orders made by each user id

# %%
#Check output
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  product_id                product_name  aisle_id  \
# 0            0           1  Chocolate Sandwich Cookies        61
# 1            0           1  Chocolate Sandwich Cookies        61
# 2            0           1  Chocolate Sandwich Cookies        61
# 3            0           1  Chocolate Sandwich Cookies        61
# 4            0           1  Chocolate Sandwich Cookies        61
# ..         ...         ...                         ...       ...
# 95           0           1  Chocolate Sandwich Cookies        61
# 96           0           1  Chocolate Sandwich Cookies        61
# 97           0           1  Chocolate Sandwich Cookies        61
# 98           0           1  Chocolate Sandwich Cookies        61
# 99           0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  order_id  user_id  order_number  order_day_of_week  \
# 0              19     5.8   3139998      138            28                  6
# 1              19     5.8   1977647      138            30                  6
# 2              19     5.8    389851      709             2                  0
# 3              19     5.8    652770      764             1                  3
# 4              19     5.8   1813452      764             3                  4
# ..            ...     ...       ...      ...           ...                ...
# 95             19     5.8    602103    10831             8                  3
# 96             19     5.8     49629    11119            18                  1
# 97             19     5.8    317888    11186            13                  5
# 98             19     5.8    682486    11243            16                  3
# 99             19     5.8   2861386    11448            10                  2
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     NaN                 10          0
# 4                  17                     9.0                 11          1
# ..                ...                     ...                ...        ...
# 95                 11                    23.0                  5          0
# 96                 14                    30.0                  1          0
# 97                 16                     2.0                  8          0
# 98                 13                     0.0                  2          0
# 99                 15                     3.0                  6          0
#
#    _merge    price_range_loc    busiest_days busiest_period_of_day  max_order
# 0    both  Mid-range product  Regularly busy           Most orders         32
# 1    both  Mid-range product  Regularly busy        Average orders         32
# 2    both  Mid-range product    Busiest days        Average orders          5
# 3    both  Mid-range product    Slowest days           Most orders          3
# 4    both  Mid-range product    Slowest days        Average orders          3
# ..    ...                ...             ...                   ...        ...
# 95   both  Mid-range product    Slowest days           Most orders         10
# 96   both  Mid-range product    Busiest days           Most orders         23
# 97   both  Mid-range product  Regularly busy           Most orders         26
# 98   both  Mid-range product    Slowest days           Most orders         43
# 99   both  Mid-range product  Regularly busy           Most orders         21
#
# [100 rows x 19 columns]

# %% [markdown]
# ## 5. Deriving Columns with loc()

# %%
#create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] >10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Check value counts
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# **Observations:**
# - Most customers are within the 'regular customer' category
# - least customers considered 'new customer'

# %%
#Determine if the prices of products purchased by loyal customers differ from those purchased by regular or new customers
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.772831  1.0  25.0
# New customer      7.800320  1.0  25.0
# Regular customer  7.797431  1.0  25.0

# %% [markdown]
# **Observations:**
# - There is not much difference in the prices of products purchased by loyal, regular or new customers
# - For each customer type, the average price of products purchased is about $7.80

# %%
#Check flags assigned properly
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1

# %%
#Export df with new columns
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','IC24 Prepared Data', 'ords_prods_merge_derived_new_variable.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)
