# %% [markdown]
# # Data Wranging

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/kimkmiz/Documents/Instacart Basket Analysis 2024'

# %%
#read files for department.csv
df=pd.read_csv(os.path.join(path, '02 Data', 'IC24 Original Data', 'departments.csv'), index_col = False)

# %%
#rename dataframe
df_dep=pd.read_csv(os.path.join(path, '02 Data', 'IC24 Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#Change rows to columns
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#change columns to rows
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#rename transposed dataframe
df_dep_t = df_dep.T

# %%
#view new dataframe
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#view new dataframe
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#add index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#create new header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#delete first row
df_dep_t_new=df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#add new header
df_dep_t_new.columns=new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#create data dictionary for values in department_id column
data_dict=df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#read files for products.csv
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'IC24 Original Data', 'products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#read files for department.csv
df_ords=pd.read_csv(os.path.join(path, '02 Data', 'IC24 Original Data', 'orders.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# #Create a subset for df_prods that contains data from the Snack department

# %%
#create subset for snacks
df_snacks=df_prods[df_prods['department_id']==19]

# %%
#indexing breakdown
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %% [markdown]
# #Save results to new dataframe called df_snacks

# %%
df_snacks=df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#loc function practice
df_snacks_2=df_prods.loc[df_prods['department_id']==19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#isin practice
df_snacks_3=df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#isin practice, finding multiple department_ids
df_snacks_3=df_prods.loc[df_prods['department_id'].isin([17, 18, 19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                             product_name  aisle_id  \
# 0            1               Chocolate Sandwich Cookies        61
# 13          14           Fresh Scent Dishwasher Cleaner        74
# 14          15                 Overnight Diapers Size 6        56
# 15          16            Mint Chocolate Flavored Syrup       103
# 24          25  Salted Caramel Lean Protein & Fiber Bar         3
#
#     department_id  prices
# 0              19     5.8
# 13             17     6.5
# 14             18    11.2
# 15             19     5.2
# 24             19     1.9

# %% [markdown]
# #import orders.csv data

# %%
#read orders.csv
df_ords=pd.read_csv(os.path.join(path, '02 Data', 'IC24 Original Data', 'orders.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#drop column "eval_set" without manipulating dataset
df_ords_2 = df_ords.drop(columns=['eval_set'])

# %%
df_ords_2.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## TASK 4.4

# %% [markdown]
# ## Find identifier variable that does not need to be in numeric form

# %%
#change data type for order_id and user_id in orders data frame to STRING
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %% [markdown]
# ## Find unintuitive variable and change name without overwriting

# %%
#order_dow column in df_ords is unintuitive
#change order_dow to order_day_of_week
df_ords_2 = df_ords.rename(columns={'order_dow': 'order_day_of_week'})

# %% [markdown]
# ## Find busiest hour for placing orders

# %%
#finding list of orders for each hour of the day in order to find busiest hour
df_ords['order_hour_of_day'].value_counts(dropna = True)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# #The busiest hour for placing orders is 10:00 AM

# %% [markdown]
# ## Determine the meaning of 4 in 'department_id' using the data dictionary

# %%
#print information for department id that equals 4
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# #The meaning of the value 4 is produce. This is the identifier for all items that fall within the produce category.

# %% [markdown]
# ## Create a subset of all breakfast items

# %%
#locate breakfast items id
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# #department ID for breakfast foods is 14

# %%
#creating subset for breakfast items using department id 14
df_prods_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
#print subset to check
df_prods_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# ## Prepare for observations for dinner party type of foods

# %% [markdown]
# #Create subset of all dinner related foods

# %%
#subset to include products for alcohol using id 5, deli using id 20, beverages using id 7, and meat/seafood using id 12
df_prods_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
#print subset to check
df_prods_dinner_party.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %% [markdown]
# ## How many rows does the last dataframe have?

# %%
#find rows
df_prods_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# ## Extract all info about user with user id 1

# %%
#info about user with user id 1
df_user1=df_ords.loc[df_ords['user_id'] == '1']
df_user1
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
# 5   3367565       1    prior             6          2                  7
# 6    550135       1    prior             7          1                  9
# 7   3108588       1    prior             8          1                 14
# 8   2295261       1    prior             9          1                 16
# 9   2550362       1    prior            10          4                  8
# 10  1187899       1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# ## Stats for user behavior

# %%
#stats about the user behavior
df_user1.describe()
# Out:
#        order_number  order_dow  order_hour_of_day  days_since_prior_order
# count     11.000000  11.000000          11.000000               10.000000
# mean       6.000000   2.636364          10.090909               19.000000
# std        3.316625   1.286291           3.477198                9.030811
# min        1.000000   1.000000           7.000000                0.000000
# 25%        3.500000   1.500000           7.500000               14.250000
# 50%        6.000000   3.000000           8.000000               19.500000
# 75%        8.500000   4.000000          13.000000               26.250000
# max       11.000000   4.000000          16.000000               30.000000

# %% [markdown]
# ## Notes on user behavior

# %% [markdown]
# #On average, the user orders in the start of the week. Half of the time the orders from this user are placed at 8am, but the average time of the orders are 10am.

# %% [markdown]
# ## Export Data

# %%
#export orders data frame
df_ords.to_csv(os.path.join(path, '02 Data','IC24 Prepared Data', 'orders_wrangled.csv'))

# %%
#export departments data frame
df_dep_t_new.to_csv(os.path.join(path, '02 Data','IC24 Prepared Data', 'departments_wrangled.csv'))
